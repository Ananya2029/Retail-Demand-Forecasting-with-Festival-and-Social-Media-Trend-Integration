# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)

# %% [markdown]
# Load Festival Dataset

# %%
df = pd.read_csv(
    "../data/processed/festival_enriched_sales.csv"
)

df["Date"] = pd.to_datetime(df["Date"])

print(df.shape)

df.head()
# Out:
# (6435, 24)
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  ...  WeekendFlag  Festival_Flag  \
# 0  211.096358         8.106  2010      2  ...            0              0
# 1  211.242170         8.106  2010      2  ...            0              1
# 2  211.289143         8.106  2010      2  ...            0              1
# 3  211.319643         8.106  2010      2  ...            0              1
# 4  211.350143         8.106  2010      3  ...            0              1
#
# ...

# %% [markdown]
# Create Base Trend Score

# %%
sales_scaled = (
    (df["Weekly_Sales"] - df["Weekly_Sales"].min())
    /
    (df["Weekly_Sales"].max() - df["Weekly_Sales"].min())
)

df["Trend_Score"] = (
    sales_scaled * 40
    +
    df["Festival_Score"] * 5
    +
    np.random.normal(10, 5, len(df))
)

# %% [markdown]
# Normalize Trend Score (0–100)

# %%
df["Trend_Score"] = (
    100 *
    (
        df["Trend_Score"]
        -
        df["Trend_Score"].min()
    )
    /
    (
        df["Trend_Score"].max()
        -
        df["Trend_Score"].min()
    )
)

df["Trend_Score"] = df["Trend_Score"].round(2)

# %%
df["Trend_Score"].describe()
# Out:
# count    6435.000000
# mean       38.378561
# std        20.418925
# min         0.000000
# 25%        20.110000
# 50%        33.250000
# 75%        56.300000
# max       100.000000
# Name: Trend_Score, dtype: float64

# %% [markdown]
# Generate Mention Count

# %%
df["Mention_Count"] = (

    df["Trend_Score"] * 100

    +

    np.random.randint(
        500,
        5000,
        len(df)
    )

).astype(int)

# %% [markdown]
# ### Generate Engagement Rate
#
# Range: 1% to 20%

# %%
df["Engagement_Rate"] = (

    0.01

    +

    (
        df["Trend_Score"] / 100
    ) * 0.19

    +

    np.random.normal(
        0,
        0.01,
        len(df)
    )

)

df["Engagement_Rate"] = np.clip(
    df["Engagement_Rate"],
    0.01,
    0.20
)

df["Engagement_Rate"] = (
    df["Engagement_Rate"] * 100
).round(2)

# %% [markdown]
# ### Generate Sentiment Score
#
# Range: -1 to +1

# %%
df["Sentiment_Score"] = (

    np.random.normal(
        0.2,
        0.3,
        len(df)
    )

    +

    (
        df["Festival_Score"] / 20
    )

)

df["Sentiment_Score"] = np.clip(
    df["Sentiment_Score"],
    -1,
    1
)

df["Sentiment_Score"] = (
    df["Sentiment_Score"]
).round(3)

# %% [markdown]
# ### Influencer Promotion Flag
#
# Higher trend = higher probability.

# %%
probability = (
    df["Trend_Score"] / 100
)

df["Influencer_Promotion_Flag"] = np.where(

    np.random.rand(len(df))
    <
    probability,

    1,

    0
)

# %% [markdown]
# Viral Campaign Feature

# %%
df["Viral_Campaign_Flag"] = np.where(

    (
        df["Trend_Score"] > 80
    )

    &

    (
        df["Influencer_Promotion_Flag"] == 1
    ),

    1,

    0
)

# %% [markdown]
# Verify Features

# %%
social_cols = [

    "Trend_Score",

    "Mention_Count",

    "Engagement_Rate",

    "Sentiment_Score",

    "Influencer_Promotion_Flag",

    "Viral_Campaign_Flag"

]

df[social_cols].head()
# Out:
#    Trend_Score  Mention_Count  Engagement_Rate  Sentiment_Score  \
# 0        30.12           5908             6.40            0.105
# 1        56.02           6544            11.93            0.225
# 2        59.49          10060            11.47            0.994
# 3        71.22          11999            15.74            0.818
# 4        64.28           9335            14.37            0.632
#
#    Influencer_Promotion_Flag  Viral_Campaign_Flag
# 0                          0                    0
# 1                          0                    0
# 2                          1                    0
# 3                          1                    0
# 4                          1                    0

# %% [markdown]
# Trend Score vs Sales

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Trend_Score",
    y="Weekly_Sales"
)

plt.title(
    "Trend Score vs Weekly Sales"
)

plt.show()

# %% [markdown]
# Sentiment vs Sales

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Sentiment_Score",
    y="Weekly_Sales"
)

plt.title(
    "Sentiment Score vs Weekly Sales"
)

plt.show()

# %% [markdown]
# Mentions vs Sales

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Mention_Count",
    y="Weekly_Sales"
)

plt.title(
    "Mention Count vs Weekly Sales"
)

plt.show()

# %% [markdown]
# Correlation Analysis

# %%
social_features = [

    "Weekly_Sales",

    "Trend_Score",

    "Mention_Count",

    "Engagement_Rate",

    "Sentiment_Score",

    "Influencer_Promotion_Flag"

]

plt.figure(figsize=(10,6))

sns.heatmap(

    df[social_features]
    .corr(),

    annot=True,

    cmap="coolwarm"

)

plt.title(
    "Social Media Features Correlation"
)

plt.show()

# %% [markdown]
# Save Dataset

# %%
df.to_csv(
    "../data/processed/social_media_enriched_sales.csv",
    index=False
)

print(
    "Social media enriched dataset saved successfully!"
)
# Out:
# Social media enriched dataset saved successfully!
