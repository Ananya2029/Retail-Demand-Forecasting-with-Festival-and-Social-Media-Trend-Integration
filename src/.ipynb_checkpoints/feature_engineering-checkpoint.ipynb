# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv(
    "../data/processed/social_media_enriched_sales.csv"
)

df["Date"] = pd.to_datetime(df["Date"])

print(df.shape)

df.head()
# Out:
# (6435, 30)
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  ...  Festival_Month  \
# 0  211.096358         8.106  2010      2  ...               0
# 1  211.242170         8.106  2010      2  ...               2
# 2  211.289143         8.106  2010      2  ...               2
# 3  211.319643         8.106  2010      2  ...               3
# 4  211.350143         8.106  2010      3  ...               3
#
#    Festival_Impact_Score  Pre_Festival_Flag  Post_Festival_Flag  Trend_Score  \
# ...

# %% [markdown]
# Sort Data

# %%
df = df.sort_values(
    ["Store", "Date"]
)

df.reset_index(
    drop=True,
    inplace=True
)

# %% [markdown]
# ### Lag Features
#
# Create historical sales features.

# %%
df["Lag_1"] = df.groupby(
    "Store"
)["Weekly_Sales"].shift(1)

df["Lag_4"] = df.groupby(
    "Store"
)["Weekly_Sales"].shift(4)

df["Lag_12"] = df.groupby(
    "Store"
)["Weekly_Sales"].shift(12)

# %% [markdown]
# Rolling Statistics

# %%
df["Rolling_Mean_4"] = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .transform(
          lambda x: x.rolling(4).mean()
      )

)

df["Rolling_Std_4"] = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .transform(
          lambda x: x.rolling(4).std()
      )

)

# %% [markdown]
# Moving Average

# %%
df["Moving_Average_8"] = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .transform(
          lambda x: x.rolling(8).mean()
      )

)

# %% [markdown]
# ### Interaction Features
#
# Festival × Trend

# %%
df["Festival_Trend"] = (

    df["Festival_Score"]

    *

    df["Trend_Score"]

)

# %% [markdown]
# Festival × Sentiment

# %%
df["Festival_Sentiment"] = (

    df["Festival_Score"]

    *

    df["Sentiment_Score"]

)

# %% [markdown]
# Trend × Engagement

# %%
df["Trend_Engagement"] = (

    df["Trend_Score"]

    *

    df["Engagement_Rate"]

)

# %% [markdown]
# Sales Growth

# %%
df["Sales_Growth"] = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .pct_change()

)

# %% [markdown]
# Store Average Sales

# %%
store_avg = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .transform("mean")

)

df["Store_Avg_Sales"] = store_avg

# %% [markdown]
# Store Sales Rank

# %%
store_rank = (

    df.groupby("Store")
      ["Weekly_Sales"]
      .transform("mean")
      .rank()

)

df["Store_Sales_Rank"] = store_rank

# %% [markdown]
# ### Fill NaNs Created by Lags
#
# Lag features create missing values at the start.

# %%
df.fillna(
    method="bfill",
    inplace=True
)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check New Features

# %%
new_features = [

    "Lag_1",
    "Lag_4",
    "Lag_12",

    "Rolling_Mean_4",
    "Rolling_Std_4",

    "Moving_Average_8",

    "Festival_Trend",
    "Festival_Sentiment",
    "Trend_Engagement",

    "Sales_Growth",

    "Store_Avg_Sales",
    "Store_Sales_Rank"

]

df[new_features].head()
# Out:
#         Lag_1      Lag_4     Lag_12  Rolling_Mean_4  Rolling_Std_4  \
# 0  1643690.90  1643690.9  1643690.9     1576836.025  112353.415114
# 1  1643690.90  1643690.9  1643690.9     1576836.025  112353.415114
# 2  1641957.44  1643690.9  1643690.9     1576836.025  112353.415114
# 3  1611968.17  1643690.9  1643690.9     1576836.025  112353.415114
# 4  1409727.59  1643690.9  1643690.9     1554614.970  103135.002548
#
#    Moving_Average_8  Festival_Trend  Festival_Sentiment  Trend_Engagement  \
# 0        1522329.76            0.00               0.000          192.7680
# 1        1522329.76          336.12               1.350          668.3186
# 2        1522329.76          356.94               5.964          682.3503
# 3        1522329.76          569.76               6.544         1121.0028
# 4        1522329.76          514.24               5.056          923.7036
#
#    Sales_Growth  Store_Avg_Sales  Store_Sales_Rank
# 0     -0.001055     1.555264e+06            5220.0
# ...

# %% [markdown]
# Correlation with Target

# %%
corr = (

    df.select_dtypes(
        include=np.number
    )

    .corr()["Weekly_Sales"]

    .sort_values(
        ascending=False
    )

)

corr.head(20)
# Out:
# Weekly_Sales                 1.000000
# Rolling_Mean_4               0.976341
# Moving_Average_8             0.965696
# Store_Avg_Sales              0.957818
# Lag_1                        0.951759
# Store_Sales_Rank             0.943476
# Lag_4                        0.938001
# Lag_12                       0.915683
# Rolling_Std_4                0.444479
# Trend_Engagement             0.331182
# Trend_Score                  0.330053
# Engagement_Rate              0.324820
# Mention_Count                0.277283
# Viral_Campaign_Flag          0.239202
# Sales_Growth                 0.152606
# Influencer_Promotion_Flag    0.148377
# Festival_Trend               0.135235
# Month                        0.076143
# Week                         0.074211
# Quarter                      0.063363
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# Save Final Feature Dataset

# %%
df.to_csv(
    "../data/processed/final_featured_sales.csv",
    index=False
)

print(
    "Final feature engineered dataset saved!"
)
# Out:
# Final feature engineered dataset saved!
